# %%
import os
from pathlib import Path

iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')
if iskaggle: path = Path('../input/titanic')
else:
    path = Path('titanic')
    if not path.exists():
        import zipfile, kaggle
        kaggle.api.competition_download_cli(str(path))
        zipfile.ZipFile(f'{path}.zip').extractall(path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8 if not path.exists():
#       9     import zipfile, kaggle
# ---> 10     kaggle.api.competition_download_cli(str(path))
#      11     zipfile.ZipFile(f'{path}.zip').extractall(path)
#
# File ~/Developer/personal/ai-engineering-learning/.venv/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:1155, in KaggleApi.competition_download_cli(self, competition, competition_opt, file_name, path, force, quiet)
#    1153 else:
#    1154   if file_name is None:
# -> 1155     self.competition_download_files(competition, path, force, quiet)
#    1156   else:
#    1157     self.competition_download_file(competition, file_name, path, force,
#    1158                                    quiet)
#
# File ~/Developer/personal/ai-engineering-learning/.venv/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:1116, in KaggleApi.competition_download_files(self, competition, path, force, quiet)
#    1114 request = ApiDownloadDataFilesRequest()
#    1115 request.competition_name = competition
# -> 1116 response = kaggle.competitions.competition_api_client.download_data_files(
#    1117     request)
#    1118 url = response.url.split('?')[0]
#    1119 outfile = os.path.join(effective_path,
#    1120                        competition + '.' + url.split('.')[-1])
#
# File ~/Developer/personal/ai-engineering-learning/.venv/lib/python3.12/site-packages/kagglesdk/competitions/services/competition_api_service.py:129, in CompetitionApiClient.download_data_files(self, request)
#     126 if request is None:
#     127   request = ApiDownloadDataFilesRequest()
# --> 129 return self._client.call("competitions.CompetitionApiService", "ApiDownloadDataFiles", request, HttpRedirect)
#
# File ~/Developer/personal/ai-engineering-learning/.venv/lib/python3.12/site-packages/kagglesdk/kaggle_http_client.py:126, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#     123 settings = self._session.merge_environment_settings(http_request.url, {}, None, None, None)
#     124 http_response = self._session.send(http_request, **settings)
# --> 126 response = self._prepare_response(response_type, http_response)
#     127 return response
#
# File ~/Developer/personal/ai-engineering-learning/.venv/lib/python3.12/site-packages/kagglesdk/kaggle_http_client.py:191, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     189 def _prepare_response(self, response_type, http_response):
#     190   self._print_response(http_response)
# --> 191   http_response.raise_for_status()
#     192   if 'application/json' in http_response.headers['Content-Type']:
#     193     resp = http_response.json()
#
# File ~/Developer/personal/ai-engineering-learning/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.kaggle.com/api/v1/competitions/data/download-all/datasets/titanic
